# %% [markdown]
# <img src="https://raw.githubusercontent.com/alan-barzilay/NLPortugues/master/imagens/logo_nlportugues.png"   width="150" align="right">
#
#
#
# # Lista 1 - spaCy

# %% [markdown]
# ---

# %% [markdown]
# O [spaCy]("https://spacy.io") é uma bilbioteca Python de código fonte [aberto]("https://github.com/explosion/spaCy") para Processamento de
# Linguagem Natural, constantemente atualizada e mantida. Essa biblioteca é capaz de
# processar diversas línguas, inclusive o português.
#
# ### Instalação

# %%
# %pip install spacy -U
# Out:
# Collecting spacy
#   Downloading spacy-3.7.5-cp310-cp310-win_amd64.whl (12.1 MB)
#      ---------------------------------------- 0.0/12.1 MB ? eta -:--:--
#      ---------------------------------------- 0.1/12.1 MB 3.6 MB/s eta 0:00:04
#      -- ------------------------------------- 0.7/12.1 MB 7.9 MB/s eta 0:00:02
#      ------ --------------------------------- 2.0/12.1 MB 14.5 MB/s eta 0:00:01
#      ------------ --------------------------- 3.9/12.1 MB 20.6 MB/s eta 0:00:01
#      ------------------ --------------------- 5.6/12.1 MB 24.0 MB/s eta 0:00:01
#      ------------------------ --------------- 7.4/12.1 MB 26.1 MB/s eta 0:00:01
#      ------------------------------ --------- 9.1/12.1 MB 29.0 MB/s eta 0:00:01
#      ----------------------------------- --- 10.9/12.1 MB 38.5 MB/s eta 0:00:01
#      --------------------------------------  12.1/12.1 MB 38.6 MB/s eta 0:00:01
#      --------------------------------------- 12.1/12.1 MB 31.2 MB/s eta 0:00:00
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.23.5)
# Collecting typer<1.0.0,>=0.3.0
#   Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#      ---------------------------------------- 0.0/47.2 kB ? eta -:--:--
#      ---------------------------------------- 47.2/47.2 kB ? eta 0:00:00
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.4.0-py3-none-any.whl (182 kB)
#      ---------------------------------------- 0.0/182.0 kB ? eta -:--:--
#      ---------------------------------------- 182.0/182.0 kB ? eta 0:00:00
# Requirement already satisfied: setuptools in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy) (58.1.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy) (4.65.0)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.28.2)
# Requirement already satisfied: jinja2 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.1.4)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4
#   Downloading pydantic-2.7.4-py3-none-any.whl (409 kB)
#      ---------------------------------------- 0.0/409.0 kB ? eta -:--:--
#      ------------------------------------- 409.0/409.0 kB 26.6 MB/s eta 0:00:00
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.8-cp310-cp310-win_amd64.whl (481 kB)
#      ---------------------------------------- 0.0/481.9 kB ? eta -:--:--
#      ------------------------------------- 481.9/481.9 kB 29.5 MB/s eta 0:00:00
# Collecting thinc<8.3.0,>=8.2.2
#   Downloading thinc-8.2.5-cp310-cp310-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#      ---------------------------------- ----- 1.3/1.5 MB 40.0 MB/s eta 0:00:01
#      ---------------------------------------- 1.5/1.5 MB 31.3 MB/s eta 0:00:00
# Collecting weasel<0.5.0,>=0.1.0
#   Downloading weasel-0.4.1-py3-none-any.whl (50 kB)
#      ---------------------------------------- 0.0/50.3 kB ? eta -:--:--
#      ---------------------------------------- 50.3/50.3 kB 2.5 MB/s eta 0:00:00
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.10-cp310-cp310-win_amd64.whl (25 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.9-cp310-cp310-win_amd64.whl (122 kB)
#      ---------------------------------------- 0.0/122.2 kB ? eta -:--:--
#      ---------------------------------------- 122.2/122.2 kB ? eta 0:00:00
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.8-cp310-cp310-win_amd64.whl (39 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy) (21.3)
# Collecting language-data>=1.2
#   Downloading language_data-1.2.0-py3-none-any.whl (5.4 MB)
#      ---------------------------------------- 0.0/5.4 MB ? eta -:--:--
#      ------------- -------------------------- 1.8/5.4 MB 39.0 MB/s eta 0:00:01
#      -------------------------- ------------- 3.5/5.4 MB 38.0 MB/s eta 0:00:01
#      ---------------------------------------  5.4/5.4 MB 38.3 MB/s eta 0:00:01
#      ---------------------------------------- 5.4/5.4 MB 31.4 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from packaging>=20.0->spacy) (3.0.9)
# Collecting pydantic-core==2.18.4
#   Downloading pydantic_core-2.18.4-cp310-none-win_amd64.whl (1.9 MB)
#      ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#      ----- ---------------------------------- 0.3/1.9 MB 16.4 MB/s eta 0:00:01
#      ---------------------------------------- 1.9/1.9 MB 40.5 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.6.3)
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.12)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.11-cp310-cp310-win_amd64.whl (6.6 MB)
#      ---------------------------------------- 0.0/6.6 MB ? eta -:--:--
#      ---------- ----------------------------- 1.7/6.6 MB 36.6 MB/s eta 0:00:01
#      ------------------- -------------------- 3.2/6.6 MB 33.9 MB/s eta 0:00:01
#      --------------------------- ------------ 4.6/6.6 MB 32.4 MB/s eta 0:00:01
#      ---------------------------------------  6.6/6.6 MB 35.1 MB/s eta 0:00:01
#      ---------------------------------------- 6.6/6.6 MB 28.2 MB/s eta 0:00:00
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Requirement already satisfied: colorama in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.5)
# Collecting rich>=10.11.0
#   Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#      ---------------------------------------- 0.0/240.7 kB ? eta -:--:--
#      ------------------------------------- 240.7/240.7 kB 14.4 MB/s eta 0:00:00
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: click>=8.0.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.3)
# Collecting colorama
#   Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0
#   Downloading cloudpathlib-0.18.1-py3-none-any.whl (47 kB)
#      ---------------------------------------- 0.0/47.3 kB ? eta -:--:--
#      ---------------------------------------- 47.3/47.3 kB ? eta 0:00:00
# Collecting smart-open<8.0.0,>=5.2.1
#   Downloading smart_open-7.0.4-py3-none-any.whl (61 kB)
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ---------------------------------------- 61.2/61.2 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from jinja2->spacy) (2.1.1)
# Collecting marisa-trie>=0.7.7
#   Downloading marisa_trie-1.2.0-cp310-cp310-win_amd64.whl (152 kB)
#      ---------------------------------------- 0.0/152.4 kB ? eta -:--:--
#      -------------------------------------- 152.4/152.4 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.14.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.2.0)
# Requirement already satisfied: wrapt in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.14.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Installing collected packages: cymem, spacy-loggers, spacy-legacy, smart-open, shellingham, pydantic-core, murmurhash, marisa-trie, colorama, cloudpathlib, catalogue, blis, annotated-types, wasabi, srsly, rich, pydantic, preshed, language-data, typer, langcodes, confection, weasel, thinc, spacy
#   Attempting uninstall: colorama
#     Found existing installation: colorama 0.4.5
#     Uninstalling colorama-0.4.5:
#       Successfully uninstalled colorama-0.4.5
# Successfully installed annotated-types-0.7.0 blis-0.7.11 catalogue-2.0.10 cloudpathlib-0.18.1 colorama-0.4.6 confection-0.1.5 cymem-2.0.8 langcodes-3.4.0 language-data-1.2.0 marisa-trie-1.2.0 murmurhash-1.0.10 preshed-3.0.9 pydantic-2.7.4 pydantic-core-2.18.4 rich-13.7.1 shellingham-1.5.4 smart-open-7.0.4 spacy-3.7.5 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.5 typer-0.12.3 wasabi-1.1.3 weasel-0.4.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
#     WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Após instalar o pacote spaCy devemos baixar as ferramentas específicas para o português  com o seguinte comando:

# %%
# !python -m spacy download pt_core_news_sm
# Out:
# Collecting pt-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-3.7.0/pt_core_news_sm-3.7.0-py3-none-any.whl (13.0 MB)
#      ---------------------------------------- 0.0/13.0 MB ? eta -:--:--
#      ---------------------------------------- 0.1/13.0 MB 4.3 MB/s eta 0:00:03
#      -- ------------------------------------- 0.8/13.0 MB 9.8 MB/s eta 0:00:02
#      ------- -------------------------------- 2.3/13.0 MB 18.4 MB/s eta 0:00:01
#      ------------ --------------------------- 4.2/13.0 MB 24.2 MB/s eta 0:00:01
#      ------------------ --------------------- 5.9/13.0 MB 26.7 MB/s eta 0:00:01
#      ----------------------- ---------------- 7.5/13.0 MB 28.1 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.3/13.0 MB 29.7 MB/s eta 0:00:01
#      --------------------------------- ----- 11.1/13.0 MB 38.5 MB/s eta 0:00:01
#      --------------------------------------  13.0/13.0 MB 38.6 MB/s eta 0:00:01
#      --------------------------------------- 13.0/13.0 MB 31.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from pt-core-news-sm==3.7.0) (3.7.5)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.23.5)
# Requirement already satisfied: setuptools in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (58.1.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (4.65.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.7.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.28.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (21.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: jinja2 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.1.4)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.12.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.4.0)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.4.1)
# Requirement already satisfied: language-data>=1.2 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from packaging>=20.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (4.6.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.26.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.0.12)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: colorama in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.4.6)
# Requirement already satisfied: rich>=10.11.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (13.7.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (8.1.3)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.5.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.1.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.14.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.2.0)
# Requirement already satisfied: wrapt in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.14.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.1.2)
# Installing collected packages: pt-core-news-sm
# Successfully installed pt-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\dougl\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Uma vez que temos o pacote instalado e os módulos para português baixado,  podemos começar a utilizar  o spaCy, importando o pacote e carregando o módulo para português.
#
# **Nota:** Caso seus resultados sejam diferentes dos descritos neste texto isso provavelmente significa que você está utilizando uma versão diferente do spaCy, como essa ferramenta é atualizada com frequência não é incomum encontrar discrepâncias nos resultados.

# %%
import spacy
import pt_core_news_sm
spacyPT = pt_core_news_sm.load()

# %%
spacy.__version__
# Out:
# '3.7.5'

# %% [markdown]
# É importante notar que o spaCy assume que os caracteres estão codificados no formato utf-8.  O primeiro passo portanto é gerar uma entrada nesse formato e submetê-la ao módulo carregado.

# %%
entrada = spacyPT("Mais vale um asno que me carregue que um cavalo que me derrube.")
entrada
# Out:
# Mais vale um asno que me carregue que um cavalo que me derrube.

# %% [markdown]
# ### Tokenização (itemização)
#
# A entrada que acabamos de gerar é uma sequência iterável de tokens (itens,
# ou instâncias de palavras). Se quisermos verificar qual o texto contido nessa
# sequência iterável,  usamos:

# %%
entrada.text
# Out:
# 'Mais vale um asno que me carregue que um cavalo que me derrube.'

# %% [markdown]
# Se quisermos dividir a entrada em token,  podemos utilizar o método __split__:

# %%
entrada.text.split()
# Out:
# ['Mais',
#  'vale',
#  'um',
#  'asno',
#  'que',
#  'me',
#  'carregue',
#  'que',
#  'um',
#  'cavalo',
#  'que',
#  'me',
#  'derrube.']

# %% [markdown]
# Note que o ponto  final foi absorvido pela palavra;  o mesmo teria acontecido com
# outros sinais de pontuação a utilizar  o método __split__. Para separar a pontuação
# das palavras utilizamos a  tokenização implícita realizada pelo comando __in__:

# %%
[token for token in entrada]
# Out:
# [Mais, vale, um, asno, que, me, carregue, que, um, cavalo, que, me, derrube, .]

# %% [markdown]
# Note que os streams não estão entre aspas,  pois na realidade esta lista contém uma sequência de objetos da classe __Token__.
#
# Se o objetivo é obter uma lista de Strings,  podemos proceder da seguinte maneira.

# %%
[token.text for token in entrada]
# Out:
# ['Mais',
#  'vale',
#  'um',
#  'asno',
#  'que',
#  'me',
#  'carregue',
#  'que',
#  'um',
#  'cavalo',
#  'que',
#  'me',
#  'derrube',
#  '.']

# %% [markdown]
# E para eliminar totalmente a pontuação da lista,  é só restringirr  a sua criação usando __is_punct__.

# %%
[token.text for token in entrada if not token.is_punct]
# Out:
# ['Mais',
#  'vale',
#  'um',
#  'asno',
#  'que',
#  'me',
#  'carregue',
#  'que',
#  'um',
#  'cavalo',
#  'que',
#  'me',
#  'derrube']

# %% [markdown]
# O spaCy já vem treinado para realizar etiquetagem morfossintática (PoS tagging),  o que pode ser mostrado da seguinte maneira.

# %%
[(token.text, token.pos_) for token in entrada]
# Out:
# [('Mais', 'ADV'),
#  ('vale', 'VERB'),
#  ('um', 'DET'),
#  ('asno', 'NOUN'),
#  ('que', 'PRON'),
#  ('me', 'PRON'),
#  ('carregue', 'VERB'),
#  ('que', 'SCONJ'),
#  ('um', 'DET'),
#  ('cavalo', 'NOUN'),
#  ('que', 'PRON'),
#  ('me', 'PRON'),
#  ('derrube', 'VERB'),
#  ('.', 'PUNCT')]

# %% [markdown]
# A assistência do etiquetador nos permite fazer buscas bastante sofisticadas. Por exemplo podemos buscar os lemas de todos os verbos encontrados  na sentença.

# %%
[token.lemma_ for token in entrada if token.pos_ == 'VERB']
# Out:
# ['valer', 'carregar', 'derrube']

# %% [markdown]
# Os lemas de verbos conjugados nos fornecem  a sua forma infinitiva.

# %% [markdown]
# ### Reconhecimento de entidades nomeadas
#
# A biblioteca já vem treinada com um  mecanismo que permite o reconhecimento de
# entidades nomeadas.

# %%
texto2 = spacyPT("A CBF fez um pedido de análise ao Comitê de Apelações da FIFA a fim de diminuir a pena do atacante Neymar, suspenso da Copa América pela Conmebol.")
print(texto2.ents)
[(entidade,entidade.label_) for entidade in texto2.ents]
# Out:
# (CBF, Comitê de Apelações da FIFA, Neymar, Copa América, Conmebol)
# [(CBF, 'ORG'),
#  (Comitê de Apelações da FIFA, 'ORG'),
#  (Neymar, 'PER'),
#  (Copa América, 'MISC'),
#  (Conmebol, 'ORG')]

# %%
texto2 = spacyPT("a dona minha sogra é muito gentil com aqueles que trabalham no ASAI")
#n reconhece asai o mercado com minuscula
print(texto2.ents)
[(entidade,entidade.label_) for entidade in texto2.ents]
# Out:
# (ASAI,)
# [(ASAI, 'ORG')]

# %% [markdown]
# ___________________________
# # <font color='blue'>  Questão 1 </font>
#
# Utilizando o spacy, extraia o nome dos personagens presentes no terceiro capitulo da obra "Mémorias postumas de Brás Cubas" de Machado de Assis

# %%
cap_3_bras_cubas = "Mas, já que falei nos meus dois tios, deixem-me fazer aqui um curto esboço genealógico.        O fundador de minha família foi um certo Damião Cubas, que floresceu na primeira metade do século XVIII. Era tanoeiro de ofício, natural do Rio de Janeiro, onde teria morrido na penúria e na obscuridade, se somente exercesse a tanoaria. Mas não; fez-se lavrador, plantou, colheu, permutou o seu produto por boas e honradas patacas, até que morreu, deixando grosso cabedal a um filho, o licenciado Luís Cubas. Neste rapaz é que verdadeiramente começa a série de meus avós -- dos avós que a minha família sempre confessou -  porque o Damião Cubas era afinal de contas um tanoeiro, e talvez mau tanoeiro, ao passo que o Luís Cubas estudou em Coimbra, primou no Estado, e foi um dos amigos particulares do vice-rei conde da Cunha.        Como este apelido de Cubas lhe cheirasse excessivamente a tanoaria, alegava meu pai, bisneto do Damião, que o dito apelido fora dado a um cavaleiro, herói nas jornadas da Africa, em prêmio da façanha que praticou arrebatando trezentas cubas ao mouros. Meu pai era homem de imaginação; escapou à tanoaria nas asas de um calembour. Era um bom caráter, meu pai, varão digno e leal como poucos. Tinha, é verdade, uns fumos de pacholice; mas quem não é um pouco pachola nesse mundo? Releva notar que ele não recorreu à inventiva senão depois de experimentar a falsificação; primeiramente, entroncou-se na família daquele meu famoso homônimo, o capitão-mor Brás Cubas, que fundou a vila de São Vicente, onde morreu em 1592, e por esse motivo é que me deu o nome de Brás. Opôs-se-lhe, porém, a família do capitão-mor, e foi então que ele imaginou as trezentas cubas mouriscas.        Vivem ainda alguns membros de minha família, minha sobrinha Venância, por exemplo, o lírio-do-vale, que é a flor das damas do seu tempo; vive o pai, o Cotrim, um sujeito que... Mas não antecipemos os sucessos; acabemos de uma vez com o nosso emplasto. "
cap_3_bras_cubas
# Out:
# 'Mas, já que falei nos meus dois tios, deixem-me fazer aqui um curto esboço genealógico.        O fundador de minha família foi um certo Damião Cubas, que floresceu na primeira metade do século XVIII. Era tanoeiro de ofício, natural do Rio de Janeiro, onde teria morrido na penúria e na obscuridade, se somente exercesse a tanoaria. Mas não; fez-se lavrador, plantou, colheu, permutou o seu produto por boas e honradas patacas, até que morreu, deixando grosso cabedal a um filho, o licenciado Luís Cubas. Neste rapaz é que verdadeiramente começa a série de meus avós -- dos avós que a minha família sempre confessou -  porque o Damião Cubas era afinal de contas um tanoeiro, e talvez mau tanoeiro, ao passo que o Luís Cubas estudou em Coimbra, primou no Estado, e foi um dos amigos particulares do vice-rei conde da Cunha.        Como este apelido de Cubas lhe cheirasse excessivamente a tanoaria, alegava meu pai, bisneto do Damião, que o dito apelido fora dado a um cavaleiro, herói nas jornadas da Africa, em prêmio da façanha que praticou arrebatando trezentas cubas ao mouros. Meu pai era homem de imaginação; escapou à tanoaria nas asas de um calembour. Era um bom caráter, meu pai, varão digno e leal como poucos. Tinha, é verdade, uns fumos de pacholice; mas quem não é um pouco pachola nesse mundo? Releva notar que ele não recorreu à inventiva senão depois de experimentar a falsificação; primeiramente, entroncou-se na família daquele meu famoso homônimo, o capitão-mor Brás Cubas, que fundou a vila de São Vicente, onde morreu em 1592, e por esse motivo é que me deu o nome de Brás. Opôs-se-lhe, porém, a família do capitão-mor, e foi então que ele imaginou as trezentas cubas mouriscas.        Vivem ainda alguns membros de minha família, minha sobrinha Venância, por exemplo, o lírio-do-vale, que é a flor das damas do seu tempo; vive o pai, o Cotrim, um sujeito que... Mas não antecipemos os sucessos; acabemos de uma vez com o nosso emplasto. '

# %%
texto_cap_3_bras_cubas = spacyPT(cap_3_bras_cubas)
[(entidade,entidade.label_) for entidade in texto_cap_3_bras_cubas.ents if entidade.label_ == "PER"]
# Out:
# [(Damião Cubas, 'PER'),
#  (Luís Cubas, 'PER'),
#  (Damião Cubas, 'PER'),
#  (Luís Cubas, 'PER'),
#  (conde da Cunha, 'PER'),
#  (Damião, 'PER'),
#  (Brás Cubas, 'PER')]

# %% [markdown]
# Quais destas repostas estão corretas?  Quais personagens estão faltando?

# %% [markdown]
# Acredito que todas as pessoas citacas sejam realmente personagens do livro, mas não seidizer se está faltando

# %% [markdown]
# # <font color='blue'>  Questão 2 </font>
#
# Extraia todos os pronomes deste capitulo.
#
# _____________
# **<font color='red'> Sua resposta aqui </font>**

# %%
[(token.text, token.pos_) for token in texto_cap_3_bras_cubas if token.pos_ == "PRON"]
# Out:
# [('que', 'PRON'),
#  ('onde', 'PRON'),
#  ('que', 'PRON'),
#  ('lhe', 'PRON'),
#  ('que', 'PRON'),
#  ('que', 'PRON'),
#  ('quem', 'PRON'),
#  ('ele', 'PRON'),
#  ('que', 'PRON'),
#  ('onde', 'PRON'),
#  ('me', 'PRON'),
#  ('ele', 'PRON'),
#  ('que', 'PRON'),
#  ('que', 'PRON')]

# %% [markdown]
# # <font color='blue'>  Questão 3 </font>
# Utilize os visualizadores para explorar o mapa de dependencias de uma frase a sua escolha deste capitulo.
# https://spacy.io/usage/visualizers
#
# Você pode acessar diretamente uma frase especifica ao utilizar o gerador "sents", por exemplo:
#
# ```python
# frases = [frase for frase in texto.sents]
# frases[2]
#
#
# Era tanoeiro de ofício, natural do Rio de Janeiro LOC , onde teria morrido na penúria e na obscuridade, se somente exercesse a tanoaria.
# ```
#
#
# _______________
#
#
# **<font color='red'> Sua resposta aqui </font>**

# %%
from spacy import displacy

# %%
#escolha de frases
frases = [frase for frase in texto_cap_3_bras_cubas.sents]
frases[2]
# Out:
# Era tanoeiro de ofício, natural do Rio de Janeiro, onde teria morrido na penúria e na obscuridade, se somente exercesse a tanoaria.

# %%
doc = spacyPT(frases[2].text)
displacy.serve(doc, style="dep")
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="pt">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="2902ef8108ee48108047d9844bc3d1c3-0" class="displacy" width="3900" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Era</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">tanoeiro</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">ofício,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">natural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Rio</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Janeiro,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">onde</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">teria</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">morrido</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">na</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">penúria</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">e</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">na</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">obscuridade,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">se</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">somente</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">exercesse</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">tanoaria.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2902ef8108ee48108047d9844bc3d1c3-0-0" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2902ef8108ee48108047d9844bc3d1c3-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cop</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2902ef8108ee48108047d9844bc3d1c3-0-1" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2902ef8108ee48108047d9844bc3d1c3-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2902ef8108ee48108047d9844bc3d1c3-0-2" stroke-width="2px" d="M245,352.0 C245,177.0 565.0,177.0 565.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2902ef8108ee48108047d9844bc3d1c3-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M565.0,354.0 L573.0,342.0 557.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2902ef8108ee48108047d9844bc3d1c3-0-3" stroke-width="2
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %% [markdown]
# # Fontes
# Tanto o capitulo utilizado nesta aula quanto a obra completa fazem parte do dominio publico e podem ser encontrados em http://www.dominiopublico.gov.br/download/texto/bv000215.pdf
